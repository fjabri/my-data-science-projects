# %% [markdown]
# ___
# # Apprentissage supervisé (classification)
# ---
#
# <img src="https://python.gel.ulaval.ca/media/sio-u009/mlprocess_3.png" alt="Processus d'apprentissage automatique" width="50%"/>
#
# À la fin de ce module, le participant sera apte à:
#
# - connaître les fondements des différents algorithmes de classification;
# - appliquer les bons algorithmes de classification selon le contexte d’application;
# - comprendre l’effet des hyperparamètres sur l’erreur de généralisation.
#
# Pour télécharger le PDF de ce module, [cliquez ici](https://python.gel.ulaval.ca/media/capsules/sio-u009/h20/handout_3.pdf).
#
# ## Présentation
#
# Visionnez la capsule suivante qui présente le professeur et le module :
#
# <video style="width: 100%; max-width: 600px; margin: 10px 0" controls src="https://python.gel.ulaval.ca/media/capsules/sio-u009/h20/capsule_3_1.mp4" type="video/mp4">
# Your browser does not support the video tag.
# </video>
#
# ## Introduction à l'apprentissage supervisé
#
# Visionnez la capsule suivante qui introduit l'apprentissage supervisé :
#
# <video style="width: 100%; max-width: 600px; margin: 10px 0" controls src="https://python.gel.ulaval.ca/media/capsules/sio-u009/h20/capsule_3_2.mp4" type="video/mp4">
# Your browser does not support the video tag.
# </video>
#
# ## Discriminants linéaires
#
#
# Visionnez la capsule suivante qui explique ce qu'est un discriminant linéaire et la classification binaire :
#
# <video style="width: 100%; max-width: 600px; margin: 10px 0" controls src="https://python.gel.ulaval.ca/media/capsules/sio-u009/h20/capsule_3_3.mp4" type="video/mp4">
# Your browser does not support the video tag.
# </video>
#
# ## 	Séparateurs à vastes marges
#
# Visionnez la capsule suivante qui présente les séparateurs à vaste marge :
#
# <video style="width: 100%; max-width: 600px; margin: 10px 0" controls src="https://python.gel.ulaval.ca/media/capsules/sio-u009/h20/capsule_3_4.mp4" type="video/mp4">
# Your browser does not support the video tag.
# </video>
#
# ## 	Méthodes à noyau
#
# Visionnez la capsule suivante qui explique le principe des méthodes à noyau :
#
# <video style="width: 100%; max-width: 600px; margin: 10px 0" controls src="https://python.gel.ulaval.ca/media/capsules/sio-u009/h20/capsule_3_5.mp4" type="video/mp4">
# Your browser does not support the video tag.
# </video>
#
# ## 	Méthodes par ensemble
#
# Visionnez la capsule suivante qui décris les méthodes par ensemble :
#
# <video style="width: 100%; max-width: 600px; margin: 10px 0" controls src="https://python.gel.ulaval.ca/media/capsules/sio-u009/h20/capsule_3_6.mp4" type="video/mp4">
# Your browser does not support the video tag.
# </video>
