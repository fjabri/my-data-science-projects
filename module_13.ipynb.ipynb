# %% [markdown]
# ___
# # Évaluation et Sélection des modèles
# ---
#
# <img src="https://python.gel.ulaval.ca/media/sio-u009/mlprocess_4.png" alt="Processus d'apprentissage automatique" width="50%"/>
#
# À la fin de ce module, le participant sera apte à:
#
# - comprendre la notion de métrique; connaître les principales métriques de classification et régression;
# - comparer des modèles sur la base de certaines métriques;
# - utiliser une métrique dans un cadre méthodologique de sélection de modèles;
# - connaître les métriques permettant de contrer le débalancement des classes.
#
# Pour télécharger le PDF de ce module, [cliquez ici](https://python.gel.ulaval.ca/media/capsules/sio-u009/h20/handout_4.pdf).
#
# ## Capsule vidéo
#
# Visionnez la capsule suivante qui présente les différentes façons d'évaluer adéquatement les modèles produits par les méthodes précédemment vues :
#
# <video style="width: 100%; max-width: 600px; margin: 10px 0" controls src="https://python.gel.ulaval.ca/media/capsules/sio-u009/h20/capsule_4_1.mp4" type="video/mp4">
# Your browser does not support the video tag.
# </video>
