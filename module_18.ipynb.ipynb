# %% [markdown]
# ___
# # Introduction à l'apprentissage profond
# ---
#
# <img src="https://python.gel.ulaval.ca/media/sio-u009/mlprocess_3.png" alt="Processus d'apprentissage automatique" width="50%"/>
#
#
#
# À la fin de ce module, le participant sera apte à:
#
# - Comprendre le fonctionnement d'un réseau de neurones
# - Connaître les principales fonctions de perte pour les réseaux de neurones
# - Comprendre la structure d'un réseau de neurones
# - Connaître les différentes techniques d'optimisation par descente du gradient
# - Entraîner un réseau de neurones avec un cadre méthodologique
#
# Pour télécharger le PDF de ce module, [cliquez ici](https://python.gel.ulaval.ca/media/capsules/sio-u009/h20/handout_5.pdf).
#
# ## Introduction
#
# Visionnez la capsule suivante qui introduit le contexte du développement de l'apprentissage profond:
#
# <video style="width: 100%; max-width: 600px; margin: 10px 0" controls src="https://python.gel.ulaval.ca/media/capsules/sio-u009/h20/capsule_5_1.mp4" type="video/mp4">
# Your browser does not support the video tag.
# </video>
#
# ## Classification linéaire & perceptron
#
# Visionnez la capsule suivante qui explique la notion de classification par réseaux de neurones:
#
# <video style="width: 100%; max-width: 600px; margin: 10px 0" controls src="https://python.gel.ulaval.ca/media/capsules/sio-u009/h20/capsule_5_2.mp4" type="video/mp4">
# Your browser does not support the video tag.
# </video>
#
# ## Réseaux de neurones (_feedforward_)
#
# Visionnez la capsule suivante qui détaille le fonctionnement d'un réseau de neurones:
#
# <video style="width: 100%; max-width: 600px; margin: 10px 0" controls src="https://python.gel.ulaval.ca/media/capsules/sio-u009/h20/capsule_5_3.mp4" type="video/mp4">
# Your browser does not support the video tag.
# </video>
#
# ## Considérations pratiques
#
# Visionnez la capsule suivante qui précise les ajustements à faire lors de l'apprentissage de réseaux de neurones:
#
# <video style="width: 100%; max-width: 600px; margin: 10px 0" controls src="https://python.gel.ulaval.ca/media/capsules/sio-u009/h20/capsule_5_4.mp4" type="video/mp4">
# Your browser does not support the video tag.
# </video>
#
# ## Réseaux convolutionnels
#
# Visionnez la capsule suivante qui explique le fonctionnement d'un réseau de neurones convolutionnel:
#
# <video style="width: 100%; max-width: 600px; margin: 10px 0" controls src="https://python.gel.ulaval.ca/media/capsules/sio-u009/h20/capsule_5_5.mp4" type="video/mp4">
# Your browser does not support the video tag.
# </video>
#
# ## Réseaux récurrents
#
# Visionnez la capsule suivante qui explique le fonctionnement d'un réseau de neurones récurrent:
#
# <video style="width: 100%; max-width: 600px; margin: 10px 0" controls src="https://python.gel.ulaval.ca/media/capsules/sio-u009/h20/capsule_5_6.mp4" type="video/mp4">
# Your browser does not support the video tag.
# </video>
