# %% [markdown]
# Dans les capsules vidéos ci-dessous, les intervenants de cette formation partagent diverses réflexions et conseils en lien avec leur partie respective.
#
# ### François Laviolette -- Apprentissage automatique
#
# <video style="width: 100%; max-width: 600px; margin: 20px 0" controls src="https://python.gel.ulaval.ca/media/capsules/sio-u009/h20/conclusion-laviolette.mp4" type="video/mp4">
# Your browser does not support the video tag.
# </video>
#
# ### Marie-Pier Côté -- Régression linéaire
#
# <video style="width: 100%; max-width: 600px; margin: 20px 0" controls src="https://python.gel.ulaval.ca/media/capsules/sio-u009/h20/conclusion-côté.mp4" type="video/mp4">
# Your browser does not support the video tag.
# </video>
#
# ### Christian Gagné -- Apprentissage supervisé
#
# <video style="width: 100%; max-width: 600px; margin: 20px 0" controls src="https://python.gel.ulaval.ca/media/capsules/sio-u009/h20/conclusion-gagné.mp4" type="video/mp4">
# Your browser does not support the video tag.
# </video>
#
# ### Patrick Dallaire -- Évaluation et sélection
#
# <video style="width: 100%; max-width: 600px; margin: 20px 0" controls src="https://python.gel.ulaval.ca/media/capsules/sio-u009/h20/conclusion-dallaire.mp4" type="video/mp4">
# Your browser does not support the video tag.
# </video>
#
# ### Philippe Giguère (remplacé par Frédérik Paradis) -- Apprentissage profond
#
#
# <video style="width: 100%; max-width: 600px; margin: 20px 0" controls src="https://python.gel.ulaval.ca/media/capsules/sio-u009/h20/conclusion-giguère.webm" type="video/mp4">
# Your browser does not support the video tag.
# </video>
