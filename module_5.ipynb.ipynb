# %% [markdown]
# ___
# # Introduction à l'apprentissage automatique
# ---
#
# <img src="https://python.gel.ulaval.ca/media/sio-u009/mlprocess_3.png" alt="Processus d'apprentissage automatique" width="50%"/>
#
#
# À la fin de ce module, le participant sera apte à:
#
# - comprendre le paradigme de programmation par apprentissage automatique;
# - connaître les principales formes d’apprentissage;
# - comprendre les notions de généralisation et de surapprentissage;
# - appliquer une méthodologie d’apprentissage automatique rigoureuse;
# - connaître les principaux algorithmes d’apprentissage supervisé;
# - connaître les enjeux éthiques et les limites des algorithmes d’apprentissage automatique.
#
# Pour télécharger le PDF de ce module, [cliquez ici](https://python.gel.ulaval.ca/media/capsules/sio-u009/h20/handout_1.pdf).
#
# ## Le présentateur
#
# Vous pouvez visionnez la capsule suivante qui présente l'Intelligence Artificielle succintement dans le cadre de l'[Académie de Transformation du Numérique (ATN)](https://transformation-numerique.ulaval.ca/auteur/francois-laviolette/) :
#
# [![Francois Laviolette](https://img.youtube.com/vi/4BZo3cB0qfk/0.jpg)](https://www.youtube.com/watch?v=4BZo3cB0qfk)
#
# ## Capsule Vidéo
#
# Visionnez la capsule suivante qui vous introduit aux principaux concepts de l'apprentissage automatique et vous présente les différents enjeux autour de l'intelligence artificielle :
#
# <video style="width: 100%; max-width: 600px; margin: 10px 0" controls src="https://python.gel.ulaval.ca/media/capsules/sio-u009/h20/capsule_1_1.mp4" type="video/mp4">
# Your browser does not support the video tag.
# </video>
#
# NB : La vidéo de la slide 43 ne voulait pas s'insérer pour des raisons techniques, nous vous avons donc mis le lien ci dessous pour la visualiser pendant que Francois vous la présente.
#
# [![Slide 43](https://img.youtube.com/vi/3liCbRZPrZA/0.jpg)](https://www.youtube.com/watch?v=3liCbRZPrZA?t=4)
