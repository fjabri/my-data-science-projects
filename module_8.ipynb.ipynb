# %% [markdown]
# ___
# # Application des méthodes de régression linéaires
# ---
#
# <img src="https://python.gel.ulaval.ca/media/sio-u009/mlprocess_3.png" alt="Processus d'apprentissage automatique" width="50%"/>
#
#
# À la fin de ce module, le participant sera apte à:
#
# - connaître les fondements des modèles linéaires et de ses extensions;
# - appliquer les méthodes d’inférence pour un modèle linéaire;
# - faire la sélection des variables explicatives; utiliser un modèle linéaire pour effectuer des prévisions.
#
# Pour télécharger le PDF de ce module, [cliquez ici](https://python.gel.ulaval.ca/media/capsules/sio-u009/h20/handout_2.pdf).
#
# ## Introduction
#
# Visionnez la capsule suivante qui introduit les motivations à produire des modèles linéaires explicables :
#
# <video style="width: 100%; max-width: 600px; margin: 10px 0" controls src="https://python.gel.ulaval.ca/media/capsules/sio-u009/h20/capsule_2_1.mp4" type="video/mp4">
# Your browser does not support the video tag.
# </video>
#
# ## Régression linéaire simple
#
# Visionnez la capsule suivante qui explique la notion de regression linéaire simple :
#
# <video style="width: 100%; max-width: 600px; margin: 10px 0" controls src="https://python.gel.ulaval.ca/media/capsules/sio-u009/h20/capsule_2_2.mp4" type="video/mp4">
# Your browser does not support the video tag.
# </video>
#
# ## Régression linéaire multiple
#
# Visionnez la capsule suivante qui explique la notion de regression linéaire multiple :
#
# <video style="width: 100%; max-width: 600px; margin: 10px 0" controls src="https://python.gel.ulaval.ca/media/capsules/sio-u009/h20/capsule_2_3.mp4" type="video/mp4">
# Your browser does not support the video tag.
# </video>
#
# ## Modèle linaire généralisés
#
# Avant de passer à la capsule sur les modèles linéaires généralisés, veuillez regarder ce court vidéo qui permettra de mettre en contexte l'exemple qui sera étudié :
#
# [![Challenger disaster](https://img.youtube.com/vi/j4JOjcDFtBE/0.jpg)](https://www.youtube.com/watch?v=j4JOjcDFtBE)
#
# Visionnez la capsule suivante qui introduit les modèles linéaires généralisés (GLM) :
#
# <video style="width: 100%; max-width: 600px; margin: 10px 0" controls src="https://python.gel.ulaval.ca/media/capsules/sio-u009/h20/capsule_2_4.mp4" type="video/mp4">
# Your browser does not support the video tag.
# </video>
